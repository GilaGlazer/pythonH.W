# %% [markdown]
# #### 1. Dataframe basics

# %% [markdown]
# #### 1.1. Import pandas and reffered the package as pd + Load "telecom_churn.csv" and assign in to the variable df <span style= color:#0033cc>(3 points)</span>

# %%
pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in c:\python310\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.3-cp310-cp310-win_amd64.whl (11.6 MB)
# Installing collected packages: pandas
# Successfully installed pandas-2.2.3
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
df = pd.read_csv('telecom_churn.csv')
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1  False
# 1                          1  False
# 2                          0  False
# 3                          2  False
# 4                          3  False
# ...                      ...    ...
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False
#
# [3333 rows x 20 columns]

# %% [markdown]
# #### 1.2 Return the column labels/names <span style= color:#0033cc>(2 points)</span>

# %%
columns_name = df.columns.tolist()
columns_name
# Out:
# ['State',
#  'Account length',
#  'Area code',
#  'International plan',
#  'Voice mail plan',
#  'Number vmail messages',
#  'Total day minutes',
#  'Total day calls',
#  'Total day charge',
#  'Total eve minutes',
#  'Total eve calls',
#  'Total eve charge',
#  'Total night minutes',
#  'Total night calls',
#  'Total night charge',
#  'Total intl minutes',
#  'Total intl calls',
#  'Total intl charge',
#  'Customer service calls',
#  'Churn']

# %% [markdown]
# #### 1.3 Print the df shape <span style= color:#0033cc>(3 points)</span>

# %%
df.shape
# Out:
# (3333, 20)

# %% [markdown]
# #### 2. What is the total day calls given by state and area code?

# %% [markdown]
# #### 2.1 Group the df by state and area code (assign it to grouped variable). <span style= color:#0033cc>(5 points)</span>

# %%
calls = df.groupby(['State','Area code'])['Total day calls']

# %% [markdown]
# #### 2.2 Use agg with the desired function sum to get the final answer (assign it to telecom_agg variable).<span style= color:#0033cc>(5 points)</span>

# %%
telecom_agg = calls.agg('sum').reset_index()
telecom_agg
# Out:
#     State  Area code  Total day calls
# 0      AK        408             1342
# 1      AK        415             2357
# 2      AK        510             1255
# 3      AL        408             2524
# 4      AL        415             4090
# ..    ...        ...              ...
# 148    WV        415             5474
# 149    WV        510             3491
# 150    WY        408             1659
# 151    WY        415             4205
# 152    WY        510             2007
#
# [153 rows x 3 columns]

# %% [markdown]
# #### 2.3 Reset the group by index <span style= color:#0033cc>(3 points)</span>

# %%
newTelecom= telecom_agg.reset_index()
newTelecom
# Out:
#      index State  Area code  Total day calls
# 0        0    AK        408             1342
# 1        1    AK        415             2357
# 2        2    AK        510             1255
# 3        3    AL        408             2524
# 4        4    AL        415             4090
# ..     ...   ...        ...              ...
# 148    148    WV        415             5474
# 149    149    WV        510             3491
# 150    150    WY        408             1659
# 151    151    WY        415             4205
# 152    152    WY        510             2007
#
# [153 rows x 4 columns]

# %% [markdown]
# #### 2.4 Use head function to review the first 10 telecom_agg rows <span style= color:#0033cc>(3 points)</span>

# %%
telecom_agg.head(10)
# Out:
#   State  Area code  Total day calls
# 0    AK        408             1342
# 1    AK        415             2357
# 2    AK        510             1255
# 3    AL        408             2524
# 4    AL        415             4090
# 5    AL        510             1314
# 6    AR        408             1382
# 7    AR        415             2756
# 8    AR        510             1480
# 9    AZ        408             1452

# %% [markdown]
# #### 3. Users Churn rate

# %% [markdown]
# #### 3.1 Change "Churn" column type to an integer: <span style= color:#0033cc>(3 points)</span>

# %%
df['Churn'] = df['Churn'].astype(int)
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0                45.07              197.4               99             16.78
# 1                27.47              195.5              103             16.62
# 2                41.38              121.2              110             10.30
# 3                50.90               61.9               88              5.26
# 4                28.34              148.3              122             12.61
# ...                ...                ...              ...               ...
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 0                          1      0
# 1                          1      0
# 2                          0      0
# 3                          2      0
# 4                          3      0
# ...                      ...    ...
# 3328                       2      0
# 3329                       3      0
# 3330                       2      0
# 3331                       2      0
# 3332                       0      0
#
# [3333 rows x 20 columns]

# %% [markdown]
# #### 3.2 what is the users "churn rate" in our dataframe? <span style= color:#0033cc>(5 points)</span>
# Hint: the churn rate formula can be calculated as the "number of churned" divided by the "total number of customers".

# %%
churnRate = df["Churn"].sum() / df.shape[0]
churnRate
# Out:
# np.float64(0.14491449144914492)

# %% [markdown]
# #### 3.3  How the charn rate can affect on the company? <span style= color:#0033cc>(3 points)</span>

# %% [markdown]
# #### 3.4 How much time (on average) do churned users spend on the phone during daytime? <span style= color:#0033cc>(5 points)</span>
# Hint: filter churn column when the value of churn equal to 1

# %%
churned = df[df['Churn'] == 1]
churned = churned['Total day minutes'].mean()
churned
# Out:
# np.float64(206.91407867494823)

# %% [markdown]
# #### 3.5 What is the maximum length of international calls among loyal users who do not have an international plan? ('International plan' == 'No') <span style= color:#0033cc>(5 points)</span>
# Hint: 2 filters conditions,churn equal to 0 and international plan equal to no

# %%
c = df[df['International plan']=='No']
c = c[c['Churn'] == 0]
maxC = c['Total intl minutes'].max()
maxC
# Out:
# np.float64(18.9)

# %% [markdown]
# #### 4. Select top 3 international plan subscribers and non subscribers with the most intl calls

# %% [markdown]
# #### 4.1. Build a function top which attributes df, n (for the top n) and column. In this function use sort_values to sort the values in the column specified. <span style= color:#0033cc>(10 points)</span>
# Note: Do not apply the function on the whole data frame (e.i. top(df, n=3)) as the output will be the top 3 regardless of subscribers and non-subscribers.

# %%
def top(df,n,column):
    return df.sort_values(by=column,ascending=False).head(n)

# %% [markdown]
# #### 4.2. Group the df dataframe by 'International plan' and use apply(top) to apply this function. <span style= color:#0033cc>(5 points)</span>

# %%
result = df.groupby('International plan').apply(lambda x: top(x, n=3, column='Total intl minutes'))
result
# Out:
# C:\Users\huser\AppData\Local\Temp\ipykernel_13592\929084110.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   result = df.groupby('International plan').apply(lambda x: top(x, n=3, column='Total intl minutes'))
#                         State  Account length  Area code International plan  \
# International plan
# No                 314     ID             128        408                 No
#                    1816    OR              53        415                 No
#                    2816    ID             130        415                 No
# Yes                115     ME              36        510                Yes
#                    1420    MI              81        415                Yes
#                    214     FL              70        510                Yes
#
#                         Voice mail plan  Number vmail messages  \
# International plan
# No                 314               No                      0
#                    1816              No                      0
#                    2816              No                      0
# Yes                115              Yes                     42
#                    1420              No                      0
#                    214               No                      0
#
#                          Total day minutes  Total day calls  Total day charge  \
# International plan
# No                 314               125.2               99             21.28
#                    1816              184.8               98             31.42
#                    2816              263.7              113             44.83
# Yes                115               196.8               89             33.46
#                    1420              149.4               68             25.40
#                    214               226.7               98             38.54
#
#                          Total eve minutes  Total eve calls  Total eve charge  \
# International plan
# No                 314               205.4              107             17.46
#                    1816              216.4              125             18.39
#                    2816              186.5              103             15.85
# Yes                115               254.9              122             21.67
#                    1420              171.9               98             14.61
#                    214               228.1              115             19.39
#
#                          Total night minutes  Total night calls  \
# International plan
# No                 314                 254.4                111
#                    1816                141.1                116
#                    2816                195.3                 99
# Yes                115                 138.3                126
#                    1420                214.5                 97
#                    214                  73.2                 93
#
#                          Total night charge  Total intl minutes  \
# International plan
# No                 314                11.45                18.9
#                    1816                6.35                18.4
#                    2816                8.79                18.3
# Yes                115                 6.22                20.0
#                    1420                9.65                17.9
#                    214                 3.29                17.6
#
#                          Total intl calls  Total intl charge  \
# International plan
# No                 314                  2               5.10
#                    1816                 3               4.97
#                    2816                 6               4.94
# Yes                115                  6               5.40
#                    1420                 3               4.83
#                    214                  4               4.75
#
#                          Customer service calls  Churn
# International plan
# No                 314                        0      0
#                    1816                       2      0
#                    2816                       1      1
# Yes                115                        0      1
#                    1420                       3      1
#                    214                        2      1

# %% [markdown]
# #### 5. pd.crosstab

# %% [markdown]
# #### 5.1 how the observations in our sample are normalized (divide each value by the sum of the values) in the context of two variables - Churn and Voice mail plan. To do so, build a contingency table using the crosstab method. <span style= color:#0033cc>(6 points)</span>
# Hint: To normalize using all values, simply set normalize=True

# %%
contingency_table = pd.crosstab(df['Churn'], df['Voice mail plan'], normalize=True)
contingency_table
# Out:
# Voice mail plan        No       Yes
# Churn
# 0                0.602460  0.252625
# 1                0.120912  0.024002

# %% [markdown]
# #### 5.2 What is the conclustion of most of users regarding voice mail usage? <span style= color:#0033cc>(4 points)</span>

# %% [markdown]
# #### 6. Columns calculations

# %% [markdown]
# #### 6.1 Add a column name 'total_charge', and get the total charge by sum all the charge columns <span style= color:#0033cc>(7 points)</span>

# %%
df['total_charge'] = df[['Total day charge', 'Total eve charge', 'Total night charge']].sum(axis=1)
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  ...  Total eve charge  \
# 0                45.07              197.4  ...             16.78
# 1                27.47              195.5  ...             16.62
# 2                41.38              121.2  ...             10.30
# 3                50.90               61.9  ...              5.26
# 4                28.34              148.3  ...             12.61
# ...                ...                ...  ...               ...
# 3328             26.55              215.5  ...             18.32
# 3329             39.29              153.4  ...             13.04
# 3330             30.74              288.8  ...             24.55
# 3331             36.35              159.6  ...             13.57
# 3332             39.85              265.9  ...             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 0                   244.7                 91               11.01
# 1                   254.4                103               11.45
# 2                   162.6                104                7.32
# 3                   196.9                 89                8.86
# 4                   186.9                121                8.41
# ...                   ...                ...                 ...
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 0                   10.0                 3               2.70
# 1                   13.7                 3               3.70
# 2                   12.2                 5               3.29
# 3                    6.6                 7               1.78
# 4                   10.1                 3               2.73
# ...                  ...               ...                ...
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn  total_charge
# 0                          1      0         72.86
# 1                          1      0         55.54
# 2                          0      0         59.00
# 3                          2      0         65.02
# 4                          3      0         49.36
# ...                      ...    ...           ...
# 3328                       2      0         57.43
# 3329                       3      0         60.94
# 3330                       2      0         63.93
# 3331                       2      0         56.18
# 3332                       0      0         73.31
#
# [3333 rows x 21 columns]

# %% [markdown]
# ####  6.2 Add a column name 'Day_charge_pct', and get day charge precentage of total charge by dividing the column 'Total day charge' by the column 'total_charge'. <span style= color:#0033cc>(7 points)</span>

# %%
df['Day_charge_pct'] = df['Total day charge'] / df['total_charge'] * 100
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 0                        25              265.1              110
# 1                        26              161.6              123
# 2                         0              243.4              114
# 3                         0              299.4               71
# 4                         0              166.7              113
# ...                     ...                ...              ...
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  ...  Total night minutes  \
# 0                45.07              197.4  ...                244.7
# 1                27.47              195.5  ...                254.4
# 2                41.38              121.2  ...                162.6
# 3                50.90               61.9  ...                196.9
# 4                28.34              148.3  ...                186.9
# ...                ...                ...  ...                  ...
# 3328             26.55              215.5  ...                279.1
# 3329             39.29              153.4  ...                191.3
# 3330             30.74              288.8  ...                191.9
# 3331             36.35              159.6  ...                139.2
# 3332             39.85              265.9  ...                241.4
#
#       Total night calls  Total night charge  Total intl minutes  \
# 0                    91               11.01                10.0
# 1                   103               11.45                13.7
# 2                   104                7.32                12.2
# 3                    89                8.86                 6.6
# 4                   121                8.41                10.1
# ...                 ...                 ...                 ...
# 3328                 83               12.56                 9.9
# 3329                123                8.61                 9.6
# 3330                 91                8.64                14.1
# 3331                137                6.26                 5.0
# 3332                 77               10.86                13.7
#
#       Total intl calls  Total intl charge  Customer service calls  Churn  \
# 0                    3               2.70                       1      0
# 1                    3               3.70                       1      0
# 2                    5               3.29                       0      0
# 3                    7               1.78                       2      0
# 4                    3               2.73                       3      0
# ...                ...                ...                     ...    ...
# 3328                 6               2.67                       2      0
# 3329                 4               2.59                       3      0
# 3330                 6               3.81                       2      0
# 3331                10               1.35                       2      0
# 3332                 4               3.70                       0      0
#
#       total_charge  Day_charge_pct
# 0            72.86       61.858358
# 1            55.54       49.459849
# 2            59.00       70.135593
# 3            65.02       78.283605
# 4            49.36       57.414911
# ...            ...             ...
# 3328         57.43       46.230193
# 3329         60.94       64.473252
# 3330         63.93       48.083842
# 3331         56.18       64.702741
# 3332         73.31       54.358205
#
# [3333 rows x 22 columns]

# %% [markdown]
# #### 7. Day charge percentage and state visualization

# %% [markdown]
# #### 7.1 Import matplotlib.pyplot and referred the package as plt <span style= color:#0033cc>(2 points)</span>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### 7.2 create new string list with the name 'my_color' that contains the following colors names: red,green,orange,blue,yellow <span style= color:#0033cc>(4 points)</span>

# %%
my_color = ['red', 'green', 'orange', 'blue', 'yellow']

# %% [markdown]
# #### 7.3 Bar chart plot <span style= color:#0033cc>(10 points)</span>

# %% [markdown]
# 1.Select first 5 rows of the dataframe (use df.iloc[])

# %% [markdown]
# 2.Use <span style= color:blue>df.plot</span> function with kind='bar' and x='State' and y='Day_charge_pct' and color = my_colors to make a simple bar chart plot (of the day chart %).

# %% [markdown]
# 3.Use <span style= color:blue>plt.xlabel("State Code")</span> and <span style= color:blue>plt.ylabel("Day Charge %")</span> to label the corresponding axes

# %%
df_subset = df.iloc[:5]

df_subset.plot(kind='bar', x='State', y='Day_charge_pct', color=my_color)

plt.xlabel("State Code")
plt.ylabel("Day Charge %")

plt.show()
